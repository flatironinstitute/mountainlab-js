# %%
import ephysviz as viz
import numpy as np
from mltools import mlstudy as mls
from mltools import mlproc as mlp
import imp

# %%
mlp.runProcess('ephys.compute_templates',{"timeseries":'data/pre.mda.prv',"firings":'data/firings.mda.prv'},{"templates_out":'data/templates.mda'},{"clip_size":100})
# Out:
# RUNNING:::::: ml-run-process ephys.compute_templates --inputs timeseries:data/pre.mda.prv firings:data/firings.mda.prv --parameters clip_size:100 --outputs templates_out:data/templates.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Initializing process ... ]
# [ Running ... ] /home/magland/main-venv/bin/python3 /home/magland/.mountainlab/packages/ml_ephys/basic/basic.py ephys.compute_templates --timeseries=/tmp/mountainlab-tmp/output_86ebdcf6e86c14c2fd0c75bd426c15ba52dfece4_timeseries_out --firings=/tmp/mountainlab-tmp/output_44d21b96454a11a23b6caaa3ac837372621ba062_firings_out --templates_out=/home/magland/src/mountainlab-js/examples/spike_sorting/001_simple_bash_example/data/templates.mda --clip_size=100 --_tempdir=/tmp/mountainlab-tmp/tempdir_6b27a7e257_o6CkmL
# Elapsed for TimeseriesChunkReader: 0.0456798 sec reading, 0.184077 sec running
#
# Elapsed time for processor ephys.compute_templates: 0.565 sec
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# {'templates_out': 'data/templates.mda'}

# %%
templates=mls.loadMdaFile('data/templates.mda')
viz.view_templates(templates)
