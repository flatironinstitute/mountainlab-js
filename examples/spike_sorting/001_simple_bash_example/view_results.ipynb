# %%
import ephysviz as viz
import numpy as np
from mltools import mlstudy as mls
from mltools import mlproc as mlp
import imp

# %%
mlp.runProcess('ms3.compute_templates',{"timeseries":'data/pre.mda.prv',"firings":'data/firings.mda.prv'},{"templates_out":'data/templates.mda'},{"clip_size":100})
# Out:
# RUNNING:::::: ml-run-process ms3.compute_templates --inputs timeseries:data/pre.mda.prv firings:data/firings.mda.prv --parameters clip_size:100 --outputs templates_out:data/templates.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Initializing process ... ]
# [ Running ... ] /home/magland/.mountainlab/packages/mountainsort/packages/ms3/bin/ms3.mp ms3.compute_templates --timeseries=/tmp/mountainlab-tmp/output_86ebdcf6e86c14c2fd0c75bd426c15ba52dfece4_timeseries_out --firings=/tmp/mountainlab-tmp/output_44d21b96454a11a23b6caaa3ac837372621ba062_firings_out --templates_out=/home/magland/src/mountainlab-js/examples/spike_sorting/001_simple_bash_example/data/templates.mda --clip_size=100 --clusters= --_tempdir=/tmp/mountainlab-tmp/tempdir_739b9ed207_qAgdDr
# computing templates (M=4,T=100,K=24,L=35637)...
#
# Elapsed time for processor ms3.compute_templates: 0.166 sec
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# {'templates_out': 'data/templates.mda'}

# %%
templates=mls.loadMdaFile('data/templates.mda')
viz.view_templates(templates)
